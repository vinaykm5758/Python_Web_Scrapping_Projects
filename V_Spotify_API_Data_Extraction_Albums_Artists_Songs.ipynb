# %%
# Project Info: Extract the Spotify datasets using spotify APP
# created on 2023-08-06

#!pip install spotipy

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#Input Credentials

## ENTER YOUR CLIENT_ID and CLIENT_SECRET
client_credentials_manager = SpotifyClientCredentials(client_id="", client_secret="")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f"

# %%
playlist_link.split("/")
# Out:
# ['https:',
#  '',
#  'open.spotify.com',
#  'playlist',
#  '37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f']

# %%
playlist_link.split("/")[-1]
# Out:
# '37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f'

# %%
playlist_link.split("/")[-1].split('?')
# Out:
# ['37i9dQZEVXbNG2KDcFcKOF', 'si=1333723a6eff4b7f']

# %%
playlist_link.split("/")[-1].split('?')[0]
# Out:
# '37i9dQZEVXbNG2KDcFcKOF'

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
data['items']
# Out:
# [{'added_at': '2023-08-04T10:10:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#       'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#       'id': '6HaGTQPmzraVmaVxvz6EUc',
#       'name': 'Jung Kook',
#       'type': 'artist',
#       'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#       'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#       'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#       'name': 'Latto',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}],
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2023-08-04T10:10:51Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#      'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#      'id': '6HaGTQPmzraVmaVxvz6EUc',
#      'name': 'Jung Kook',
#      'type': 'artist',
#      'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#      'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#      'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#      'name': 'Latto',
#      'type': 'artist',
#      'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}],
# ...

# %%
data['items'][0]['track']['album']['id']
data['items'][0]['track']['album']['name']
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#    'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#    'id': '6HaGTQPmzraVmaVxvz6EUc',
#    'name': 'Jung Kook',
#    'type': 'artist',
#    'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#    'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#    'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#    'name': 'Latto',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
# ...

# %%
data['items'][0]['track']['album']
# Out:
# {'album_type': 'single',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#    'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#    'id': '6HaGTQPmzraVmaVxvz6EUc',
#    'name': 'Jung Kook',
#    'type': 'artist',
#    'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#    'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#    'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#    'name': 'Latto',
#    'type': 'artist',
#    'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}],
#  'available_markets': ['AD',
#   'AE',
#   'AG',
#   'AL',
#   'AM',
#   'AO',
#   'AR',
#   'AT',
#   'AU',
#   'AZ',
#   'BA',
#   'BB',
#   'BD',
#   'BE',
#   'BF',
#   'BG',
#   'BH',
#   'BI',
#   'BJ',
#   'BN',
#   'BO',
#   'BR',
#   'BS',
#   'BT',
#   'BW',
#   'BY',
#   'BZ',
#   'CA',
#   'CD',
#   'CG',
#   'CH',
#   'CI',
#   'CL',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '53985D8g3JcGBoULSOYYKX'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Seven (feat. Latto)'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-07-14'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 3

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'}

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'

# %%
album_list=[]

for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']
    #creating DICT
    album_element={'album_id':album_id,
                    'name':album_name,
                    'release_date':album_release_date,
                    'total_tracks':album_total_tracks,
                    'url':album_url}
    #print(album_element)
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '53985D8g3JcGBoULSOYYKX',
#   'name': 'Seven (feat. Latto)',
#   'release_date': '2023-07-14',
#   'total_tracks': 3,
#   'url': {'spotify': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'}},
#  {'album_id': '3puAvurwvtvi1rodndIPW8',
#   'name': 'LA VIDA ES UNA',
#   'release_date': '2023-03-23',
#   'total_tracks': 23,
#   'url': {'spotify': 'https://open.spotify.com/album/3puAvurwvtvi1rodndIPW8'}},
#  {'album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'name': 'UTOPIA',
#   'release_date': '2023-07-28',
#   'total_tracks': 19,
#   'url': {'spotify': 'https://open.spotify.com/album/18NOKLkZETa4sWwLMIm0UZ'}},
#  {'album_id': '3AafSrFIbJPH6BJHiJm1Cd',
#   'name': 'What Was I Made For? [From The Motion Picture "Barbie"]',
#   'release_date': '2023-07-13',
#   'total_tracks': 1,
#   'url': {'spotify': 'https://open.spotify.com/album/3AafSrFIbJPH6BJHiJm1Cd'}},
#  {'album_id': '18NOKLkZETa4sWwLMIm0UZ',
#   'name': 'UTOPIA',
#   'release_date': '2023-07-28',
# ...

# %%
album_list[0]
# Out:
# {'album_id': '53985D8g3JcGBoULSOYYKX',
#  'name': 'Seven (feat. Latto)',
#  'release_date': '2023-07-14',
#  'total_tracks': 3,
#  'url': {'spotify': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'}}

# %%
#################ARTISTS

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#   'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#   'id': '6HaGTQPmzraVmaVxvz6EUc',
#   'name': 'Jung Kook',
#   'type': 'artist',
#   'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#   'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#   'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#   'name': 'Latto',
#   'type': 'artist',
#   'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}]

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#   'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#   'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'name': 'Travis Scott',
#   'type': 'artist',
#   'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#   'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#   'id': '3TVXtAsR1Inumwj472S9r4',
#   'name': 'Drake',
#   'type': 'artist',
#   'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}]

# %%
data['items'][2]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#   'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#   'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'name': 'Travis Scott',
#   'type': 'artist',
#   'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/3TVXtAsR1Inumwj472S9r4'},
#   'href': 'https://api.spotify.com/v1/artists/3TVXtAsR1Inumwj472S9r4',
#   'id': '3TVXtAsR1Inumwj472S9r4',
#   'name': 'Drake',
#   'type': 'artist',
#   'uri': 'spotify:artist:3TVXtAsR1Inumwj472S9r4'}]

# %%
data['items'][2]['track']['artists'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#  'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#  'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#  'name': 'Travis Scott',
#  'type': 'artist',
#  'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}

# %%
data['items'][2]['track']['artists'][0]['id']
# Out:
# '0Y5tJX1MQlPlqiwlOH1tJY'

# %%
data['items'][2]['track']['artists'][0]['name']
# Out:
# 'Travis Scott'

# %%
data['items'][2]['track']['artists'][0]['href']
# Out:
# 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY'

# %%
data['items'][2]['track']
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#     'href': 'https://api.spotify.com/v1/artists/0Y5tJX1MQlPlqiwlOH1tJY',
#     'id': '0Y5tJX1MQlPlqiwlOH1tJY',
#     'name': 'Travis Scott',
#     'type': 'artist',
#     'uri': 'spotify:artist:0Y5tJX1MQlPlqiwlOH1tJY'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CD',
#    'CG',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
type(artist_list)
# Out:
# list

# %%
artist_list

# %%
artist_list[0]
# Out:
# {'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
#  'artist_name': 'Jung Kook',
#  'external_url': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc'}

# %%
######### SONG

# %%
data['items'][0]['track']
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6HaGTQPmzraVmaVxvz6EUc'},
#     'href': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc',
#     'id': '6HaGTQPmzraVmaVxvz6EUc',
#     'name': 'Jung Kook',
#     'type': 'artist',
#     'uri': 'spotify:artist:6HaGTQPmzraVmaVxvz6EUc'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3MdXrJWsbVzdn6fe5JYkSQ'},
#     'href': 'https://api.spotify.com/v1/artists/3MdXrJWsbVzdn6fe5JYkSQ',
#     'id': '3MdXrJWsbVzdn6fe5JYkSQ',
#     'name': 'Latto',
#     'type': 'artist',
#     'uri': 'spotify:artist:3MdXrJWsbVzdn6fe5JYkSQ'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
# ...

# %%
data['items'][0]['track']['id']
# Out:
# '7x9aauaA9cu6tyfpHnqDLo'

# %%
data['items'][0]['track']['name']
# Out:
# 'Seven (feat. Latto) (Explicit Ver.)'

# %%
data['items'][0]['track']['duration_ms']
# Out:
# 184400

# %%
data['items'][0]['track']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/track/7x9aauaA9cu6tyfpHnqDLo'

# %%
data['items'][0]['track']['popularity']
# Out:
# 100

# %%
data['items'][0]['added_at']
# Out:
# '2023-08-04T10:10:51Z'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '53985D8g3JcGBoULSOYYKX'

# %%
data['items'][0]['track']['album']['artists'][0]['id']
# Out:
# '6HaGTQPmzraVmaVxvz6EUc'

# %%
# Lets combine all the columns

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
type(song_list)
# Out:
# list

# %%
song_list[0]
# Out:
# {'song_id': '7x9aauaA9cu6tyfpHnqDLo',
#  'song_name': 'Seven (feat. Latto) (Explicit Ver.)',
#  'duration_ms': 184400,
#  'url': 'https://open.spotify.com/track/7x9aauaA9cu6tyfpHnqDLo',
#  'popularity': 100,
#  'song_added': '2023-08-04T10:10:51Z',
#  'album_id': '53985D8g3JcGBoULSOYYKX',
#  'artist_id': '6HaGTQPmzraVmaVxvz6EUc'}

# %%
#album_list
#artist_list
#song_list

# %%
album_list[0]
#artist_list
#song_list
# Out:
# {'album_id': '53985D8g3JcGBoULSOYYKX',
#  'name': 'Seven (feat. Latto)',
#  'release_date': '2023-07-14',
#  'total_tracks': 3,
#  'url': {'spotify': 'https://open.spotify.com/album/53985D8g3JcGBoULSOYYKX'}}

# %%
artist_list[0]
# Out:
# {'artist_id': '6HaGTQPmzraVmaVxvz6EUc',
#  'artist_name': 'Jung Kook',
#  'external_url': 'https://api.spotify.com/v1/artists/6HaGTQPmzraVmaVxvz6EUc'}

# %%
song_list[0]
# Out:
# {'song_id': '7x9aauaA9cu6tyfpHnqDLo',
#  'song_name': 'Seven (feat. Latto) (Explicit Ver.)',
#  'duration_ms': 184400,
#  'url': 'https://open.spotify.com/track/7x9aauaA9cu6tyfpHnqDLo',
#  'popularity': 100,
#  'song_added': '2023-08-04T10:10:51Z',
#  'album_id': '53985D8g3JcGBoULSOYYKX',
#  'artist_id': '6HaGTQPmzraVmaVxvz6EUc'}

# %%
## creating data frames 

album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  53985D8g3JcGBoULSOYYKX                                Seven (feat. Latto)
# 1  3puAvurwvtvi1rodndIPW8                                     LA VIDA ES UNA
# 2  18NOKLkZETa4sWwLMIm0UZ                                             UTOPIA
# 3  3AafSrFIbJPH6BJHiJm1Cd  What Was I Made For? [From The Motion Picture ...
# 4  18NOKLkZETa4sWwLMIm0UZ                                             UTOPIA
#
#   release_date  total_tracks  \
# 0   2023-07-14             3
# 1   2023-03-23            23
# 2   2023-07-28            19
# 3   2023-07-13             1
# 4   2023-07-28            19
#
#                                                  url
# 0  {'spotify': 'https://open.spotify.com/album/53...
# 1  {'spotify': 'https://open.spotify.com/album/3p...
# 2  {'spotify': 'https://open.spotify.com/album/18...
# 3  {'spotify': 'https://open.spotify.com/album/3A...
# 4  {'spotify': 'https://open.spotify.com/album/18...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
# DROP ANY DUPLCIATES

album_df= album_df.drop_duplicates(subset=['album_id'])

# %%
### Create ARTISTS DATA FRAME

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id   artist_name  \
# 0  6HaGTQPmzraVmaVxvz6EUc     Jung Kook
# 1  3MdXrJWsbVzdn6fe5JYkSQ         Latto
# 2  7iK8PXO48WeuP03g8YR51W   Myke Towers
# 3  0Y5tJX1MQlPlqiwlOH1tJY  Travis Scott
# 4  3TVXtAsR1Inumwj472S9r4         Drake
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 1  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 2  https://api.spotify.com/v1/artists/7iK8PXO48We...
# 3  https://api.spotify.com/v1/artists/0Y5tJX1MQlP...
# 4  https://api.spotify.com/v1/artists/3TVXtAsR1In...

# %%
# DROP ANY DUPLCIATES

artist_df= artist_df.drop_duplicates(subset=['artist_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  7x9aauaA9cu6tyfpHnqDLo                Seven (feat. Latto) (Explicit Ver.)
# 1  7ABLbnD53cQK00mhcaOUVG                                               LALA
# 2  67nepsnrcZkowTxMWigSbb                             MELTDOWN (feat. Drake)
# 3  6wf7Yu7cxBSPrRlWeSeK0Q  What Was I Made For? [From The Motion Picture ...
# 4  42VsgItocQwOQC3XWZ8JNA                         FE!N (feat. Playboi Carti)
#
#    duration_ms                                                url  popularity  \
# 0       184400  https://open.spotify.com/track/7x9aauaA9cu6tyf...         100
# 1       197920  https://open.spotify.com/track/7ABLbnD53cQK00m...          99
# 2       246133  https://open.spotify.com/track/67nepsnrcZkowTx...          93
# 3       222369  https://open.spotify.com/track/6wf7Yu7cxBSPrRl...          97
# 4       191700  https://open.spotify.com/track/42VsgItocQwOQC3...          92
#
# ...

# %%
# DROP ANY DUPLCIATES

song_df= song_df.drop_duplicates(subset=['song_id'])

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  53985D8g3JcGBoULSOYYKX                                Seven (feat. Latto)
# 1  3puAvurwvtvi1rodndIPW8                                     LA VIDA ES UNA
# 2  18NOKLkZETa4sWwLMIm0UZ                                             UTOPIA
# 3  3AafSrFIbJPH6BJHiJm1Cd  What Was I Made For? [From The Motion Picture ...
# 5  10eNMeTimUzAKLhCOpIUlb                                              K-POP
#
#   release_date  total_tracks  \
# 0   2023-07-14             3
# 1   2023-03-23            23
# 2   2023-07-28            19
# 3   2023-07-13             1
# 5   2023-07-21             1
#
#                                                  url
# 0  {'spotify': 'https://open.spotify.com/album/53...
# 1  {'spotify': 'https://open.spotify.com/album/3p...
# 2  {'spotify': 'https://open.spotify.com/album/18...
# 3  {'spotify': 'https://open.spotify.com/album/3A...
# 5  {'spotify': 'https://open.spotify.com/album/10...

# %%
artist_df.head()
# Out:
#                 artist_id   artist_name  \
# 0  6HaGTQPmzraVmaVxvz6EUc     Jung Kook
# 1  3MdXrJWsbVzdn6fe5JYkSQ         Latto
# 2  7iK8PXO48WeuP03g8YR51W   Myke Towers
# 3  0Y5tJX1MQlPlqiwlOH1tJY  Travis Scott
# 4  3TVXtAsR1Inumwj472S9r4         Drake
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 1  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 2  https://api.spotify.com/v1/artists/7iK8PXO48We...
# 3  https://api.spotify.com/v1/artists/0Y5tJX1MQlP...
# 4  https://api.spotify.com/v1/artists/3TVXtAsR1In...

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  7x9aauaA9cu6tyfpHnqDLo                Seven (feat. Latto) (Explicit Ver.)
# 1  7ABLbnD53cQK00mhcaOUVG                                               LALA
# 2  67nepsnrcZkowTxMWigSbb                             MELTDOWN (feat. Drake)
# 3  6wf7Yu7cxBSPrRlWeSeK0Q  What Was I Made For? [From The Motion Picture ...
# 4  42VsgItocQwOQC3XWZ8JNA                         FE!N (feat. Playboi Carti)
#
#    duration_ms                                                url  popularity  \
# 0       184400  https://open.spotify.com/track/7x9aauaA9cu6tyf...         100
# 1       197920  https://open.spotify.com/track/7ABLbnD53cQK00m...          99
# 2       246133  https://open.spotify.com/track/67nepsnrcZkowTx...          93
# 3       222369  https://open.spotify.com/track/6wf7Yu7cxBSPrRl...          97
# 4       191700  https://open.spotify.com/track/42VsgItocQwOQC3...          92
#
# ...

# %%
#Transformations

# %%
album_df.head()
# Out:
#                  album_id                                               name  \
# 0  53985D8g3JcGBoULSOYYKX                                Seven (feat. Latto)
# 1  3puAvurwvtvi1rodndIPW8                                     LA VIDA ES UNA
# 2  18NOKLkZETa4sWwLMIm0UZ                                             UTOPIA
# 3  3AafSrFIbJPH6BJHiJm1Cd  What Was I Made For? [From The Motion Picture ...
# 5  10eNMeTimUzAKLhCOpIUlb                                              K-POP
#
#   release_date  total_tracks  \
# 0   2023-07-14             3
# 1   2023-03-23            23
# 2   2023-07-28            19
# 3   2023-07-13             1
# 5   2023-07-21             1
#
#                                                  url
# 0  {'spotify': 'https://open.spotify.com/album/53...
# 1  {'spotify': 'https://open.spotify.com/album/3p...
# 2  {'spotify': 'https://open.spotify.com/album/18...
# 3  {'spotify': 'https://open.spotify.com/album/3A...
# 5  {'spotify': 'https://open.spotify.com/album/10...

# %%
album_df.iloc[1,2]
# Out:
# Timestamp('2023-03-23 00:00:00')

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])
# Out:
# C:\Users\Vinay\AppData\Local\Temp\ipykernel_20908\3126744046.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
album_df_copy = album_df.copy()

# %%
album_df_copy['release_date'] = pd.to_datetime(album_df_copy['release_date'])

# %%
album_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      33 non-null     object
#  1   name          33 non-null     object
#  2   release_date  33 non-null     datetime64[ns]
#  3   total_tracks  33 non-null     int64
#  4   url           33 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.5+ KB

# %%
album_df['release_date'] = album_df_copy['release_date']

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      33 non-null     object
#  1   name          33 non-null     object
#  2   release_date  33 non-null     datetime64[ns]
#  3   total_tracks  33 non-null     int64
#  4   url           33 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 1.5+ KB

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  7x9aauaA9cu6tyfpHnqDLo                Seven (feat. Latto) (Explicit Ver.)
# 1  7ABLbnD53cQK00mhcaOUVG                                               LALA
# 2  67nepsnrcZkowTxMWigSbb                             MELTDOWN (feat. Drake)
# 3  6wf7Yu7cxBSPrRlWeSeK0Q  What Was I Made For? [From The Motion Picture ...
# 4  42VsgItocQwOQC3XWZ8JNA                         FE!N (feat. Playboi Carti)
#
#    duration_ms                                                url  popularity  \
# 0       184400  https://open.spotify.com/track/7x9aauaA9cu6tyf...         100
# 1       197920  https://open.spotify.com/track/7ABLbnD53cQK00m...          99
# 2       246133  https://open.spotify.com/track/67nepsnrcZkowTx...          93
# 3       222369  https://open.spotify.com/track/6wf7Yu7cxBSPrRl...          97
# 4       191700  https://open.spotify.com/track/42VsgItocQwOQC3...          92
#
# ...

# %%
song_df_copy=song_df.copy()

# %%
song_df_copy['song_added'] = pd.to_datetime(song_df_copy['song_added'])

# %%
song_df['song_added'] = song_df_copy['song_added']

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.5+ KB

# %%
song_df.head()
# Out:
#                   song_id                                          song_name  \
# 0  7x9aauaA9cu6tyfpHnqDLo                Seven (feat. Latto) (Explicit Ver.)
# 1  7ABLbnD53cQK00mhcaOUVG                                               LALA
# 2  67nepsnrcZkowTxMWigSbb                             MELTDOWN (feat. Drake)
# 3  6wf7Yu7cxBSPrRlWeSeK0Q  What Was I Made For? [From The Motion Picture ...
# 4  42VsgItocQwOQC3XWZ8JNA                         FE!N (feat. Playboi Carti)
#
#    duration_ms                                                url  popularity  \
# 0       184400  https://open.spotify.com/track/7x9aauaA9cu6tyf...         100
# 1       197920  https://open.spotify.com/track/7ABLbnD53cQK00m...          99
# 2       246133  https://open.spotify.com/track/67nepsnrcZkowTx...          93
# 3       222369  https://open.spotify.com/track/6wf7Yu7cxBSPrRl...          97
# 4       191700  https://open.spotify.com/track/42VsgItocQwOQC3...          92
#
# ...

# %%
artist_df.head()
# Out:
#                 artist_id   artist_name  \
# 0  6HaGTQPmzraVmaVxvz6EUc     Jung Kook
# 1  3MdXrJWsbVzdn6fe5JYkSQ         Latto
# 2  7iK8PXO48WeuP03g8YR51W   Myke Towers
# 3  0Y5tJX1MQlPlqiwlOH1tJY  Travis Scott
# 4  3TVXtAsR1Inumwj472S9r4         Drake
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6HaGTQPmzra...
# 1  https://api.spotify.com/v1/artists/3MdXrJWsbVz...
# 2  https://api.spotify.com/v1/artists/7iK8PXO48We...
# 3  https://api.spotify.com/v1/artists/0Y5tJX1MQlP...
# 4  https://api.spotify.com/v1/artists/3TVXtAsR1In...

# %%
# Writing into CSV FILES

album_df.to_csv('Spotify_Albums_List_CSV_Report.csv',index=False)
artist_df.to_csv('Spotify_Artists_List_CSV_Report.csv',index=False)
song_df.to_csv('Spotify_Songs_List_CSV_Report.csv',index=False)
